# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaBarradasSanchez/EDPI/blob/main/graficas_sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %% [markdown]
# <font color=green>La libreria sympy permite realizar calculos matematicos, es decir, con simbolos en lugar de valores numericos.</font>

# %%
x=symbols('x')
x**2+5
# Out:
# x**2 + 5

# %%
c1=plotting.plot(x*x)

# %% [markdown]
# <font color=green>La funcion *.plot* nos ayuda a generar graficos.</font>

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# <font color =green>show=False indica que las graficas son almacenadas en c1 y c2, lo que permite manipularlas antes de ser observadas</font>

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %% [markdown]
# <font color=green>Agregar un elemento al final de la lista *.append*</font>

# %%
c1

# %%
c1.show()

# %% [markdown]
# <font color=green>show nos ayuda a mostrar las graficas creadas con la biblioteca matplotlib </font>

# %%
c1.extend(c2)

# %%
c1.show()

# %%
c2.show()

# %% [markdown]
# <font color=green>show nos ayuda a mostrar las graficas creadas con la biblioteca matplotlib </font>

# %%
from sympy.plotting import plot

# %%
plot(x**2)

# %% [markdown]
# <font color=green>grafica la funcion x**2 en un rango determinado </font>

# %%
plot(x**2,(x,-1,1))

# %% [markdown]
# <font color=green>grafica la funcion $$x**2$$ en el intervalo de -1 a 1 </font>

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %% [markdown]
# <font color=green>grafica la funcion exponencial en el intervalo de -1 a 1 </font>

# %%
plot(x,x**2,x**3, (x,-2,2))

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %%
s=symbols('s')

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %% [markdown]
# $T=x*3-xy+y**3$

# %%
plot3d(x**3-x*y+y**3, (x,-3,3), (y,-3,3))
